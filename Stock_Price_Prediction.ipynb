# %%
bucket_name="mystockpriceprediction"
scaler_filename = "minmax_scaler.joblib"
filename='latest_data.csv'
prefix = 'built-in-xgboost-algo'
minmax_scaler_path_key='scaler/minmax_scaler.joblib'
latest_data_path_key='latest_data/latest_data.csv'

# %%
import boto3
s3_resource=boto3.resource('s3')
s3_client = boto3.client("s3")

# %%
try:
    s3_resource.create_bucket(Bucket=bucket_name,CreateBucketConfiguration={'LocationConstraint': 'eu-north-1'})
    print('S3 bucket has been created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# S3 bucket has been created successfully

# %%
# !pip install -qU yfinance

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split  # Data splitting
from sklearn.preprocessing import MinMaxScaler  # Scaling
import yfinance as yf
import joblib
import sagemaker
from sklearn.metrics import mean_absolute_error, mean_squared_error  # Model evaluation
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [03/18/25 14:05:14] INFO     Found credentials from IAM Role:                                   ]8;id=48907;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=21080;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
#initialize parameters
start_date="2022-01-01"
end_date="2024-01-01"

# %%
#get the data
aapl=yf.download('AAPL',start=start_date,end=end_date)
aapl
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.879913  179.734962  174.653874  174.771805  104487900
# 2022-01-04  176.609634  179.793920  176.039607  179.489254   99310400
# 2022-01-05  171.911850  177.071564  171.636666  176.521197   94537600
# 2022-01-06  169.042053  172.285305  168.688244  169.730012   96904000
# 2022-01-07  169.209152  171.145275  168.088758  169.916771   86709100
# ...                ...         ...         ...         ...        ...
# 2023-12-22  192.444580  194.243775  191.818335  194.015137   37122800
# 2023-12-26  191.897873  192.732856  191.679185  192.454528   28919300
# 2023-12-27  191.997269  192.345186  189.949565  191.341219   48087700
# 2023-12-28  192.424713  193.498269  192.017156  192.981369   34049900
# 2023-12-29  191.380951  193.239786  190.585722  192.742770   42628800
#
# [501 rows x 5 columns]

# %%
def clean_df(df):
    df.columns = df.columns.droplevel(1)
    df=df.reset_index(drop=True)
    return df

# %%
aapl=clean_df(aapl)
aapl.head()
# Out:
# Price       Close        High         Low        Open     Volume
# 0      178.879913  179.734962  174.653874  174.771805  104487900
# 1      176.609634  179.793920  176.039607  179.489254   99310400
# 2      171.911850  177.071564  171.636666  176.521197   94537600
# 3      169.042053  172.285305  168.688244  169.730012   96904000
# 4      169.209152  171.145275  168.088758  169.916771   86709100

# %%
def get_features(df):
    
    #Helps model detect long-term trends.
    df['SMA_10'] = df['Close'].rolling(window=10).mean()  # 10-day simple moving average
    df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()  # 50-day Exponential Moving Average
    df['High_Low_Range'] = df['High'] - df['Low']   #Measures daily volatility, which can indicate breakouts or trend reversals.
    df['Open_Close_Change'] = (df['Close'] - df['Open'])/df['Open']  #If the Close > Open, it suggests bullish momentum; otherwise, it's bearish.
    
    # Create lag features 
    df['Close_Lag_1'] = df['Close'].shift(1)    # previous day's closing price
    df['Volume_Lag_1'] = df['Volume'].shift(1)  # Previous day's volume
 

    
    # Drop NaN values created due to rolling calculations
    df.dropna(inplace=True)
    return df

# %%
aapl2=get_features(aapl.copy())

# %%
# Define feature set (X) and target variable (y)
X = aapl2[['SMA_10' ,'EMA_50','High_Low_Range', 'Open_Close_Change','Volume_Lag_1','Close_Lag_1']]  # Input features
y= aapl2[['Close']].shift(-1)  # moves the "Close" column one step up, so each row’s target is the next day's closing price. This means for a given day's data, the model will learn to predict the closing price of the next day.

# %%
y.dropna(inplace=True)
y.rename(columns={'Close':'Target'},inplace=True)
y.head()
# Out:
# Price      Target
# 9      166.879913
# 10     163.371307
# 11     161.680878
# 12     159.616959
# 13     158.840546

# %%
X=X.head(-1)
X.head()
# Out:
# Price      SMA_10      EMA_50  High_Low_Range  Open_Close_Change  \
# 9      171.878433  176.496662        2.643741           0.010097
# 10     170.678433  176.119534        3.076162          -0.009970
# 11     169.354601  175.619604        5.051606          -0.022176
# 12     168.331503  175.072987        5.405415          -0.014792
# 13     167.388994  174.466868        3.960693          -0.012225
#
# Price  Volume_Lag_1  Close_Lag_1
# 9        84505800.0   169.228806
# 10       80440800.0   170.093658
# 11       90956700.0   166.879913
# 12       94815000.0   163.371307
# 13       91420500.0   161.680878

# %%
# Splitting into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Scale features between 0 and 1 for better model performance
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Save the scaler locally using joblib
joblib.dump(scaler, scaler_filename)
# Out:
# ['minmax_scaler.joblib']

# %%
train_data = pd.concat([y_train, pd.DataFrame(X_train_scaled)], axis=1)
test_data = pd.concat([y_test, pd.DataFrame(X_test_scaled)], axis=1)

# %%
#Store the latest 50 data entries for extracting features for inference
from io import StringIO

latest_data=aapl.tail(50)
# Convert DataFrame to CSV
csv_buffer = StringIO()
latest_data.to_csv(csv_buffer, index=False)

# %%
train_csv_path='s3://{}/{}/{}/{}'.format(bucket_name,prefix,'train','train.csv')
test_csv_path='s3://{}/{}/{}/{}'.format(bucket_name,prefix,'test','test.csv')


train_data.to_csv(train_csv_path,index=False,header= False)
test_data.to_csv(test_csv_path,index=False,header= False)
s3_resource.Bucket(bucket_name).upload_file(scaler_filename,minmax_scaler_path_key)
s3_resource.Bucket(bucket_name).put_object(Key=latest_data_path_key,Body=csv_buffer.getvalue())
# Out:
# s3.Object(bucket_name='mystockpriceprediction', key='latest_data/latest_data.csv')

# %%
from sagemaker.session import Session       #Kickstart a training session
from sagemaker.inputs import TrainingInput
from sagemaker import image_uris        #Get the container image for xgboost

# %%
xgboost_container=image_uris.retrieve("xgboost",boto3.Session().region_name,"1.2-2")
display(xgboost_container)
# Out:
# [03/18/25 14:15:35] INFO     Ignoring unnecessary instance type: None.                            ]8;id=350282;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=256751;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py#530\530]8;;\
# '662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-xgboost:1.2-2'

# %%
hyperparameters={
    "eta":"0.05",
    "num_round":"500",
    "objective":"reg:squarederror",
    "early_stopping_rounds":"10",
    "verbosity":"3",
    "subsample":"0.8",
    "min_child_weight":"8",
    "max_depth":"12",
    "gamma":"5"
}

# %%
output_path='s3://{}/{}/{}/'.format(bucket_name,prefix,'output')

# %%
estimator=sagemaker.estimator.Estimator(image_uri=xgboost_container,
                                        hyperparameters=hyperparameters,
                                        role=sagemaker.get_execution_role(),
                                        instance_count=1,
                                        instance_type='ml.m5.xlarge',
                                        output_path=output_path,
                                        volume_size=5,
                                        use_spot_instances=True,
                                        max_run=300,
                                        max_wait=600)

# %%
content_type="csv" 
train_input=TrainingInput('s3://{}/{}/{}/{}'.format(bucket_name,prefix,'train','train.csv'),content_type=content_type)
test_input=TrainingInput('s3://{}/{}/{}/{}'.format(bucket_name,prefix,'test','test.csv'),content_type=content_type)

# %%
estimator.fit({'train':train_input, 'validation':test_input})
# Out:
# [03/18/25 14:16:44] INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=342742;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=985198;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py#91\91]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
#                     INFO     Creating training-job with name:                                       ]8;id=782456;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=537902;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#1042\1042]8;;\
#                              sagemaker-xgboost-2025-03-18-14-16-44-048
# 2025-03-18 14:16:44 Starting - Starting the training job......
# ..25-03-18 14:17:36 Starting - Preparing the instances for training.
# .....03-18 14:18:14 Downloading - Downloading the training image.
# .[2025-03-18 14:19:28.783 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-03-18:14:19:28:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-03-18:14:19:28:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2025-03-18:14:19:28:INFO] No GPUs detected (normal if no gpus installed)
# [2025-03-18:14:19:28:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-03-18:14:19:28:INFO] Determined delimiter of CSV input is ','
# [2025-03-18:14:19:28:INFO] Determined delimiter of CSV input is ','
# [2025-03-18:14:19:28:INFO] Determined delimiter of CSV input is ','
# [2025-03-18:14:19:28:INFO] Determined delimiter of CSV input is ','
# [2025-03-18:14:19:28:INFO] Single node training.
# [2025-03-18:14:19:28:INFO] Train matrix has 401 rows and 6 columns
# [2025-03-18:14:19:28:INFO] Validation matrix has 198 rows
# [2025-03-18 14:19:28.863 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-03-18 14:19:28.863 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-03-18 14:19:28.864 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2025-03-18 14:19:28.864 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2025-03-18 14:19:28.864 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-03-18:14:19:28:INFO] Debug hook created from config
# [14:19:28] DEBUG: ../src/gbm/gbtree.cc:147: Using tree method: 2
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [0]#011train-rmse:147.76340#011validation-rmse:121.94438
# [2025-03-18 14:19:28.876 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO hook.py:423] Monitoring the collections: metrics
# [2025-03-18 14:19:28.880 ip-10-0-231-235.eu-north-1.compute.internal:7 INFO hook.py:486] Hook is writing from the hook with pid: 7
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [1]#011train-rmse:140.48601#011validation-rmse:116.51990
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [2]#011train-rmse:133.60889#011validation-rmse:111.67686
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [3]#011train-rmse:127.04735#011validation-rmse:107.39532
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [4]#011train-rmse:120.77744#011validation-rmse:103.65991
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [5]#011train-rmse:114.82208#011validation-rmse:100.21165
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [6]#011train-rmse:109.19865#011validation-rmse:97.30332
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [7]#011train-rmse:103.80724#011validation-rmse:94.96087
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [8]#011train-rmse:98.69830#011validation-rmse:93.04484
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [9]#011train-rmse:93.87719#011validation-rmse:91.43658
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [10]#011train-rmse:89.25177#011validation-rmse:90.16203
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [11]#011train-rmse:84.86796#011validation-rmse:89.23074
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [12]#011train-rmse:80.72206#011validation-rmse:88.73806
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [13]#011train-rmse:76.78952#011validation-rmse:88.38944
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14]#011train-rmse:73.09370#011validation-rmse:88.39874
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [15]#011train-rmse:69.51469#011validation-rmse:88.45377
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [16]#011train-rmse:66.11252#011validation-rmse:87.83696
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [17]#011train-rmse:62.89853#011validation-rmse:88.22231
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [18]#011train-rmse:59.84618#011validation-rmse:88.83093
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [19]#011train-rmse:56.93232#011validation-rmse:88.50929
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [20]#011train-rmse:54.16105#011validation-rmse:88.30135
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [21]#011train-rmse:51.51563#011validation-rmse:87.98949
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [22]#011train-rmse:48.99587#011validation-rmse:87.81110
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23]#011train-rmse:46.63061#011validation-rmse:87.86635
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [24]#011train-rmse:44.39531#011validation-rmse:88.14786
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [25]#011train-rmse:42.22980#011validation-rmse:88.25336
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [26]#011train-rmse:40.20050#011validation-rmse:88.23682
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [27]#011train-rmse:38.31564#011validation-rmse:89.12120
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [28]#011train-rmse:36.50047#011validation-rmse:89.46232
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [29]#011train-rmse:34.82652#011validation-rmse:90.30222
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [30]#011train-rmse:33.18714#011validation-rmse:90.57963
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [31]#011train-rmse:31.58294#011validation-rmse:90.67736
# [14:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [32]#011train-rmse:30.09594#011validation-rmse:90.89436
# [14:19:28] ======== Monitor: Learner ========
# [14:19:28] Configure: 1e-06s, 1 calls @ 1us
# [14:19:28] EvalOneIter: 0.001779s, 33 calls @ 1779us
# [14:19:28] GetGradient: 0.010472s, 33 calls @ 10472us
# [14:19:28] PredictRaw: 9.5e-05s, 33 calls @ 95us
# [14:19:28] UpdateOneIter: 0.014728s, 33 calls @ 14728us
# [14:19:28] ======== Monitor: GBTree ========
# [14:19:28] BoostNewTrees: 0.012794s, 33 calls @ 12794us
# [14:19:28] CommitModel: 3.4e-05s, 33 calls @ 34us
# [14:19:28] ======== Monitor: TreePruner ========
# [14:19:28] PrunerUpdate: 0.004033s, 33 calls @ 4033us
# [14:19:28] ======== Monitor: Learner ========
# [14:19:28] Configure: 0.000659s, 1 calls @ 659us
# [14:19:28] ======== Monitor: GBTree ========
# [14:19:28] ======== Monitor: TreePruner ========
#
# 2025-03-18 14:19:48 Uploading - Uploading generated training model
# 2025-03-18 14:19:48 Completed - Training job completed
# Training seconds: 115
# Billable seconds: 34
# Managed Spot Training savings: 70.4%

# %%
from sagemaker.serializers import CSVSerializer
xgb_predictor=estimator.deploy(initial_instance_count=1,instance_type='ml.m5.xlarge',serializer=CSVSerializer())
# Out:
# [03/18/25 14:20:16] INFO     Creating model with name: sagemaker-xgboost-2025-03-18-14-20-16-190    ]8;id=117218;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=422293;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#4094\4094]8;;\
#                     INFO     Creating endpoint-config with name                                     ]8;id=485351;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=608760;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#5889\5889]8;;\
#                              sagemaker-xgboost-2025-03-18-14-20-16-190
# [03/18/25 14:20:17] INFO     Creating endpoint with name sagemaker-xgboost-2025-03-18-14-20-16-190  ]8;id=19991;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=331412;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#4711\4711]8;;\
# ---------!

# %%
xgb_predictor.endpoint_name
# Out:
# 'sagemaker-xgboost-2025-03-18-14-20-16-190'

# %% [markdown]
# Making prediction using endpoint

# %%
start_date = "2024-01-01"
duration=5
test = yf.download('AAPL', start=start_date, end=pd.Timestamp(start_date)+pd.Timedelta(days=duration))
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
test=clean_df(test)
test.head()
# Out:
# Price       Close        High         Low        Open    Volume
# 0      184.532074  187.315366  182.792518  186.033057  82488700
# 1      183.150375  184.770652  182.335262  183.120556  58414500
# 2      180.824341  181.997291  179.800489  181.062899  71983600
# 3      180.098709  181.669281  179.094742  180.903888  62303300

# %%
n=len(test)
n
# Out:
# 4

# %%
aug=pd.concat([latest_data,test],axis=0)
aug
# Out:
# Price       Close        High         Low        Open     Volume
# 451    174.183395  176.546069  173.915356  174.759162   59302900
# 452    171.622131  174.143644  171.383872  174.034443   64189300
# 453    171.741257  172.743903  168.693587  169.666467   55980100
# 454    172.178070  172.406392  170.202544  171.790908   43816600
# 455    169.855103  171.800833  169.408365  170.629426   57157000
# 456    165.675735  170.133072  164.464611  169.130411   70625300
# 457    166.996048  167.730669  165.616162  165.695582   58499100
# 458    169.050964  169.924566  167.641298  167.790216   51131000
# 459    169.527496  169.656540  166.678368  168.117830   44846000
# 460    172.704224  172.962326  168.882230  169.755832   56934900
# 461    176.278015  176.486479  174.183367  174.242928   77334800
# 462    175.364700  175.533477  172.088723  172.972247   79763700
# 463    177.925934  178.124476  174.927918  175.096679   63841300
# 464    180.497101  181.112585  177.667831  177.876295   70530000
# 465    181.559296  182.115219  180.268751  181.023231   49340300
# 466    181.082779  182.780328  180.487139  181.628780   53763500
# 467    185.287567  185.456566  182.434700  182.872077   66133400
# 468    183.697098  184.919753  183.110623  184.711015   43627500
# 469    186.321350  186.987350  185.188154  186.579793   60108400
# 470    186.887939  188.369053  186.659316  186.728906   53790500
# 471    188.577805  189.820344  187.524118  188.438641   54412900
# 472    188.557922  189.243807  187.444611  189.114578   50922700
# 473    190.307419  190.764680  188.746797  188.756731   46505100
# 474    189.502243  190.376996  188.607620  190.267652   38134500
# 475    190.168243  191.778570  189.691112  190.347177   39617700
# 476    188.836243  189.760685  188.120538  189.730865   24048300
# 477    188.657318  189.532071  187.772630  188.786547   40552600
# 478    189.263672  189.939621  188.269640  188.647377   38415400
# 479    188.239822  190.943590  187.842216  189.760690   43014200
# 480    188.816376  189.184178  187.066885  188.707032   48794400
# 481    190.098663  190.416746  188.100650  189.194091   45679300
# 482    188.299454  188.915764  186.331275  188.846174   43389500
# 483    192.265640  193.239787  189.044972  189.074806   66628400
# 484    191.172226  193.597651  190.963473  193.289504   41089700
# 485    193.110580  193.836219  192.434631  192.474401   47477700
# 486    194.541992  194.820320  192.514159  193.040994   53377300
# 487    192.027084  192.335247  190.277594  191.957510   60943700
# 488    193.547974  193.557908  190.575813  191.927697   52696900
# 489    196.778564  196.818319  193.687125  193.925683   70404200
# 490    196.927673  198.428656  194.989314  196.838214   66831600
# 491    196.390900  197.215933  195.824294  196.351130  128256700
# 492    194.720917  195.456506  193.229869  194.919720   55751900
# 493    195.764648  195.774583  194.720912  194.989305   40714100
# 494    193.667252  196.500234  193.667252  195.724890   52242800
# 495    193.518127  195.903813  192.345177  194.929666   46482500
# 496    192.444580  194.243775  191.818335  194.015137   37122800
# 497    191.897873  192.732856  191.679185  192.454528   28919300
# 498    191.997269  192.345186  189.949565  191.341219   48087700
# 499    192.424713  193.498269  192.017156  192.981369   34049900
# 500    191.380951  193.239786  190.585722  192.742770   42628800
# 0      184.532074  187.315366  182.792518  186.033057   82488700
# 1      183.150375  184.770652  182.335262  183.120556   58414500
# 2      180.824341  181.997291  179.800489  181.062899   71983600
# 3      180.098709  181.669281  179.094742  180.903888   62303300

# %%
aug=get_features(aug)
aug.head()
# Out:
# Price       Close        High         Low        Open    Volume      SMA_10  \
# 460    172.704224  172.962326  168.882230  169.755832  56934900  170.353442
# 461    176.278015  176.486479  174.183367  174.242928  77334800  170.562904
# 462    175.364700  175.533477  172.088723  172.972247  79763700  170.937161
# 463    177.925934  178.124476  174.927918  175.096679  63841300  171.555629
# 464    180.497101  181.112585  177.667831  177.876295  70530000  172.387532
#
# Price      EMA_50  High_Low_Range  Open_Close_Change  Close_Lag_1  \
# 460    172.883756        4.080097           0.017368   169.527496
# 461    173.016864        2.303112           0.011680   172.704224
# 462    173.108936        3.444754           0.013831   176.278015
# 463    173.297838        3.196558           0.016158   175.364700
# 464    173.580162        3.444754           0.014734   177.925934
#
# Price  Volume_Lag_1
# 460      44846000.0
# 461      56934900.0
# 462      77334800.0
# 463      79763700.0
# 464      63841300.0

# %%
X_unseen = aug[['SMA_10' ,'EMA_50','High_Low_Range', 'Open_Close_Change','Volume_Lag_1','Close_Lag_1']].tail(n)  # Input features
X_unseen
# Out:
# Price      SMA_10      EMA_50  High_Low_Range  Open_Close_Change  \
# 0      192.234840  187.259440        4.522848          -0.008068
# 1      191.077786  187.098300        2.435390           0.000163
# 2      189.583755  186.852262        2.196802          -0.001318
# 3      188.226901  186.587417        2.574539          -0.004451
#
# Price  Volume_Lag_1  Close_Lag_1
# 0        42628800.0   191.380951
# 1        82488700.0   184.532074
# 2        58414500.0   183.150375
# 3        71983600.0   180.824341

# %%
# Reuse the same scaler fitted during training
# Download file from S3
s3_resource.Bucket(bucket_name).download_file(minmax_scaler_path_key, scaler_filename)

# Load the scaler
scaler = joblib.load(scaler_filename)
X_unseen_scaled = scaler.transform(X_unseen)

# %%
y_pred=xgb_predictor.predict(X_unseen_scaled).decode('utf-8') #byte to string
y_pred
# Out:
# '125.48660278320312\n125.48660278320312\n125.48660278320312\n125.48660278320312\n'

# %%
predictions = np.array([float(row) for row in y_pred.strip().split("\n") if row])
predictions
# Out:
# array([125.48660278, 125.48660278, 125.48660278, 125.48660278])

# %%
# Predict the next day's closing price
actual_prices = aug['Close'].shift(-1).tail(n).dropna()
predictions = predictions[:len(actual_prices)]  # Align lengths

# %%
# Calculate Mean Absolute Error (MAE) and Root Mean Squared Error (RMSE)

mae = mean_absolute_error(actual_prices, predictions)
rmse = np.sqrt(mean_squared_error(actual_prices, predictions))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Mean Absolute Error (MAE): 55.87
# Root Mean Squared Error (RMSE): 55.89

# %%
start_date = "2024-01-05"
duration=1
real_time_data = yf.download('AAPL', start=start_date, end=pd.Timestamp(start_date)+pd.Timedelta(days=duration))
real_time_data.columns = real_time_data.columns.droplevel(1)
real_time_data=np.array(real_time_data.reset_index(drop=True)).tolist()
real_time_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [[180.0987091064453,
#   181.66928147459845,
#   179.09474225448028,
#   180.90388776119542,
#   62303300.0]]
